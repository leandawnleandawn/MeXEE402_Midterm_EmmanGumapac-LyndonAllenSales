# %% [markdown]
# # Advertising Dataset
#
# ## Description:
#
# This dataset contains data on the amount spent on advertising through different channels (TV, radio, newspaper) and the resulting sales.1 It's a simple yet effective dataset for linear regression.
#
#
# ## Identification of the Variables:
#
# ### Independent Variables:
#
# 1. TV - Expenditure of the TV Advertising
# 2. Radio - Expenditure of the Radio Advertising
# 3. Newspaper - Expenditure of the Newspaper Advertising
#
# ### Dependent Variable:
#
# 1. Sales - Overall Sales of the following data
#
#
# By this we can use the Linear Regression for  this manner

# %% [markdown]
# #### Step 1: Preproccessing
#
# Importing the dataset using pandas

# %%
import pandas as pd

dataset = pd.read_csv('advertising.csv')

dataset.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
dataset.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %% [markdown]
# #### Identification of the Independent and Dependent Variables

# %%
X = dataset.iloc[:, :-1].values

X
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %%
Y = dataset.iloc[:, -1].values

Y
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 13.2,
#        17.4, 11.9, 17.8, 25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7, 17.9,
#         8.5, 16.1, 10.6, 23.2, 19.8,  9.7, 16.4, 10.7, 22.6, 21.2, 20.2,
#        23.7,  5.5, 13.2, 23.8, 18.4,  8.1, 24.2, 20.7, 14. , 16. , 11.3,
#        11. , 13.4, 18.9, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 11. , 11.8, 17.3, 11.3, 13.6, 21.7, 20.2, 12. , 16. ,
#        12.9, 16.7, 14. ,  7.3, 19.4, 22.2, 11.5, 16.9, 16.7, 20.5, 25.4,
#        17.2, 16.7, 23.8, 19.8, 19.7, 20.7, 15. ,  7.2, 12. ,  5.3, 19.8,
#        18.4, 21.8, 17.1, 20.9, 14.6, 12.6, 12.2,  9.4, 15.9,  6.6, 15.5,
#         7. , 16.6, 15.2, 19.7, 10.6,  6.6, 11.9, 24.7,  9.7,  1.6, 17.7,
#         5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 20.7, 10.9, 19.2, 20.1,
# ...

# %% [markdown]
# #### Creating the Training Set and the Test Set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
X_train
# Out:
# array([[184.9,  21. ,  22. ],
#        [195.4,  47.7,  52.9],
#        [170.2,   7.8,  35.2],
#        [121. ,   8.4,  48.7],
#        [ 17.2,   4.1,  31.6],
#        [ 16.9,  43.7,  89.4],
#        [227.2,  15.8,  49.9],
#        [280.2,  10.1,  21.4],
#        [135.2,  41.7,  45.9],
#        [ 23.8,  35.1,  65.9],
#        [ 31.5,  24.6,   2.2],
#        [ 17.9,  37.6,  21.6],
#        [220.3,  49. ,   3.2],
#        [216.4,  41.7,  39.6],
#        [209.6,  20.6,  10.7],
#        [241.7,  38. ,  23.2],
#        [281.4,  39.6,  55.8],
#        [197.6,   3.5,   5.9],
#        [213.4,  24.6,  13.1],
#        [292.9,  28.3,  43.2],
#        [ 95.7,   1.4,   7.4],
#        [ 25. ,  11. ,  29.7],
#        [ 17.2,  45.9,  69.3],
#        [ 38.2,   3.7,  13.8],
#        [163.5,  36.8,   7.4],
#        [ 97.2,   1.5,  30. ],
#        [149.8,   1.3,  24.3],
#        [ 67.8,  36.6, 114. ],
#        [239.3,  15.5,  27.3],
#        [ 85.7,  35.8,  49.3],
#        [ 68.4,  44.5,  35.6],
# ...

# %%
X_test
# Out:
# array([[250.9,  36.5,  72.3],
#        [287.6,  43. ,  71.8],
#        [ 62.3,  12.6,  18.3],
#        [222.4,   4.3,  49.8],
#        [120.2,  19.6,  11.6],
#        [ 76.4,  26.7,  22.3],
#        [120.5,  28.5,  14.2],
#        [217.7,  33.5,  59. ],
#        [164.5,  20.9,  47.4],
#        [239.8,   4.1,  36.9],
#        [134.3,   4.9,   9.3],
#        [168.4,   7.1,  12.8],
#        [210.7,  29.5,   9.3],
#        [ 13.2,  15.9,  49.6],
#        [ 25.1,  25.7,  43.3],
#        [116. ,   7.7,  23.1],
#        [218.5,   5.4,  27.4],
#        [206.9,   8.4,  26.4],
#        [125.7,  36.9,  79.2],
#        [ 78.2,  46.8,  34.5],
#        [276.7,   2.3,  23.7],
#        [234.5,   3.4,  84.8],
#        [ 13.1,   0.4,  25.6],
#        [220.5,  33.2,  37.9],
#        [265.6,  20. ,   0.3],
#        [109.8,  47.8,  51.4],
#        [131.1,  42.8,  28.9],
#        [136.2,  19.2,  16.6],
#        [243.2,  49. ,  44.3],
#        [129.4,   5.7,  31.3],
#        [ 43.1,  26.7,  35.1],
# ...

# %%
Y_train
# Out:
# array([20.5, 22.4, 16.7, 11.6,  5.9,  8.7, 19.8, 19.8, 17.2,  9.2, 11. ,
#         8. , 24.7, 22.6, 20.9, 21.8, 24.4, 16.7, 17. , 21.4, 11.9,  7.2,
#        12. ,  7.6, 18. , 13.2, 10.1, 12.5, 20.7, 13.3, 13.6, 16. , 12.4,
#         7.3, 10.3, 17.6, 17.7, 20.7, 10.4, 10.7,  6.9, 15.5, 23.8, 20.2,
#        17.1, 18.4, 16.6,  6.6, 12.9, 16.4, 20.6, 11.8, 25.4, 25.5, 10.4,
#         1.6, 17.5, 19.2, 20.2, 18.2, 16. , 19.8, 23.7, 16.5, 18. , 17.1,
#        17.3,  8.8, 25.4, 12.6, 21.7, 10.6, 18.3, 12.2, 22.3, 19.6, 11.9,
#        19. , 12.9, 14. , 17.8, 20. , 11.6,  6.6, 17.1, 11.3, 18.9, 15.6,
#        23.8,  7. , 12. , 20.9, 14.6, 13.7, 11.9, 19.6, 16.1, 21.2,  6.7,
#        22.1, 10.9, 16.4,  9.7, 10.6, 12. , 27. , 14.8, 19.9, 11.3, 12.3,
#         9.6, 15.5, 20.9, 20.7,  8.7, 15.2, 23.2,  8.1, 18.9, 10.8, 17.2,
#        10.5, 19.7,  9.7, 21.5, 10.8, 20.5, 19.7, 14.7, 16.6, 11.5, 17.6,
#        17.4,  7.6, 15. , 22.6, 16.9, 11.9, 11.9, 14. , 11.3, 16.1, 20.8,
# ...

# %%
Y_test
# Out:
# array([22.2, 26.2,  9.7, 16.7, 13.2, 11.8, 14.2, 19.4, 17.5, 17.3, 14. ,
#        16.7, 18.4,  5.6,  8.5, 11. , 17.2, 17.9, 15.9, 14.6, 16.8, 16.9,
#         5.3, 20.1, 17.4, 16.7, 16. , 13.2, 25.4, 11. , 10.1,  7.3, 17.9,
#        12.6, 24.2,  9.4, 15.3,  5.5, 20.7,  3.2])

# %% [markdown]
# ### Part 2 - Building the Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)

Y_predict
# Out:
# array([22.08362725, 24.74653807,  9.45428605, 17.22829995, 13.32522548,
#        11.67537237, 14.2611818 , 19.99030104, 15.81585842, 18.16613769,
#        12.56758494, 14.63880219, 19.25759636,  7.09783257,  8.76653868,
#        11.84949299, 17.15871799, 16.8426044 , 15.33376377, 13.8421649 ,
#        19.99486005, 17.74731877,  5.51470806, 20.136917  , 21.25783019,
#        15.63697219, 16.30019046, 14.14439273, 22.9972419 , 12.35793803,
#         9.85552074,  9.19965324, 15.63800613,  8.94772966, 23.31169864,
#         8.99884996, 14.33078391,  8.05342582, 19.36248323,  6.21309312])

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

x_function = np.arange(0,25)

plt.scatter(Y_test, Y_predict, color='r')
plt.plot(x_function, x_function, color='b')
plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.title("Comparison of Predicted and Actual Values")
plt.show()

# %% [markdown]
# ### Part 3: Evaluation

# %%
from sklearn.metrics import r2_score

r2 = r2_score(Y_test,Y_predict)

r2
# Out:
# 0.9182206210212661

# %%
k = X_test.shape[1]

n = X_test.shape[0]

adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)
adj_r2
# Out:
# 0.9114056727730383
